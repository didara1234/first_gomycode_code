# %%
from google.colab import files
import pandas as pd
uploaded = files.upload()
df = pd.read_csv('titanic-passengers.csv', sep=';')
df
# Out:
#      <input type="file" id="files-27f7e465-bfa2-4b11-8cf0-807fd00a6062" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27f7e465-bfa2-4b11-8cf0-807fd00a6062">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(axis=0,how='any',thresh=None,inplace=False)
# Out:
#      PassengerId Survived  Pclass                              Name     Sex  \
# 1             76       No       3           Moen, Mr. Sigurd Hansen    male
# 4            672       No       1            Davidson, Mr. Thornton    male
# 16           378       No       1         Widener, Mr. Harry Elkins    male
# 19           225      Yes       1      Hoyt, Mr. Frederick Maxfield    male
# 26           588      Yes       1  Frolicher-Stehli, Mr. Maxmillian    male
# ..           ...      ...     ...                               ...     ...
# 862          619      Yes       2       Becker, Miss. Marion Louise  female
# 863          858      Yes       1             Daly, Mr. Peter Denis    male
# 865          196      Yes       1              Lurette, Miss. Elise  female
# 875          463       No       1                 Gee, Mr. Arthur H    male
# 881          699       No       1          Thayer, Mr. John Borland    male
#
# ...

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
number_of_elements = len(df["Cabin"])
print("Number of elements: ",number_of_elements)
print(df["Cabin"].value_counts())
df["Cabin"].fillna('G6',inplace=True)
df
# Out:
# Number of elements:  891
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F33            3
# D              3
#               ..
# C91            1
# D45            1
# F G63          1
# A34            1
# E63            1
# Name: Cabin, Length: 147, dtype: int64
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# ...

# %%
number_of_elements = len(df["Embarked"])
print("Number of elements: ",number_of_elements)
print(df["Embarked"].value_counts())
df["Embarked"].fillna('S',inplace=True)
df
# Out:
# Number of elements:  891
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ...

# %%
import seaborn as sns
sns.boxplot(df["Age"],width=0.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print(df["Sex"].value_counts())
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.barplot(df["Sex"],df["Age"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
g= sns.FacetGrid(df,col='Survived')
g.map(sns.barplot,'Sex','Age')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df[["Age","Sex"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  28.216730
# male    30.505824

# %%
df[["Age","Sex","Survived"]].groupby(["Sex","Survived"]).mean()
# Out:
#                        Age
# Sex    Survived
# female No        26.023272
#        Yes       28.979263
# male   No        31.175224
#        Yes       27.631705

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }

# %%
df.rename(columns={"Name":"Title"}, inplace = True)
for i,j in df[["Title"]].iterrows():  #index,value
  for x in Title_Dictionary:
      if x in j["Title"]:
          df["Title"][i] = Title_Dictionary.get(x)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df
# Out:
#      PassengerId Survived  Pclass Title     Sex        Age  SibSp  Parch  \
# 0            343       No       2   Mrs    male  28.000000      0      0
# 1             76       No       3   Mrs    male  25.000000      0      0
# 2            641       No       3   Mrs    male  20.000000      0      0
# 3            568       No       3   Mrs  female  29.000000      0      4
# 4            672       No       1   Mrs    male  31.000000      1      0
# ..           ...      ...     ...   ...     ...        ...    ...    ...
# 886           10      Yes       2   Mrs  female  14.000000      1      0
# 887           61       No       3   Mrs    male  22.000000      0      0
# 888          535       No       3  Miss  female  30.000000      0      0
# 889          102       No       3   Mrs    male  29.699118      0      0
# 890          428      Yes       2   Mrs  female  19.000000      0      0
#
#          Ticket     Fare  Cabin Embarked
# 0        248740  13.0000     G6        S
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId Survived  Pclass Title     Sex        Age  SibSp  Parch  \
# 0            343       No       2   Mrs    male  28.000000      0      0
# 1             76       No       3   Mrs    male  25.000000      0      0
# 2            641       No       3   Mrs    male  20.000000      0      0
# 3            568       No       3   Mrs  female  29.000000      0      4
# 4            672       No       1   Mrs    male  31.000000      1      0
# ..           ...      ...     ...   ...     ...        ...    ...    ...
# 886           10      Yes       2   Mrs  female  14.000000      1      0
# 887           61       No       3   Mrs    male  22.000000      0      0
# 888          535       No       3  Miss  female  30.000000      0      0
# 889          102       No       3   Mrs    male  29.699118      0      0
# 890          428      Yes       2   Mrs  female  19.000000      0      0
#
#          Ticket     Fare  Cabin Embarked
# ...

# %%
df["Familysize"] = df["SibSp"]+df["Parch"]

# %%
df
# Out:
#      PassengerId Survived  Pclass Title     Sex        Age  SibSp  Parch  \
# 0            343       No       2   Mrs    male  28.000000      0      0
# 1             76       No       3   Mrs    male  25.000000      0      0
# 2            641       No       3   Mrs    male  20.000000      0      0
# 3            568       No       3   Mrs  female  29.000000      0      4
# 4            672       No       1   Mrs    male  31.000000      1      0
# ..           ...      ...     ...   ...     ...        ...    ...    ...
# 886           10      Yes       2   Mrs  female  14.000000      1      0
# 887           61       No       3   Mrs    male  22.000000      0      0
# 888          535       No       3  Miss  female  30.000000      0      0
# 889          102       No       3   Mrs    male  29.699118      0      0
# 890          428      Yes       2   Mrs  female  19.000000      0      0
#
#          Ticket     Fare  Cabin Embarked  Familysize
# ...
